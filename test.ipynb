# %% [markdown]
# <a href="https://colab.research.google.com/github/benard3360-star/hello-world/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a= 2
for i in range (a):
  print(i)
# Out:
# 0
# 1

# %%
i = 0
while(i<5):
  print("Candy purchased :", i)
i = i+1
break
# Out:
# Streaming output truncated to the last 5000 lines.
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# Candy purchased : 0
# ...

# %%
x = 3
i = 0
while x<100:
  if i == 5:
      print(i, x)
  break

# %%
i = 0
while (i < 10):
  if i % 3 !=0:
    print(i)
    i + =1
  else:
    i +=1

# %%
i = 5
for a in range (i):
  print("Candy purchased :", a)
# Out:
# Candy purchased : 0
# Candy purchased : 1
# Candy purchased : 2
# Candy purchased : 3
# Candy purchased : 4

# %%
x = ["We","Are","Cooking","With","7","Ingredients"]
print(type(x))
