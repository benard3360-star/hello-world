# %% [markdown]
# <a href="https://colab.research.google.com/github/benard3360-star/hello-world/blob/main/CalorieBurn_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dt = pd.read_csv ("/content/data.csv")
print(dt.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
#Showing the maximum number of rows contained
print(pd.options.display.max_rows)
# Out:
# 60

# %%
print(dt.head())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
#showing the information about the data
print(dt.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB
# None

# %%
#data  cleaning
#removing empty or null rows

new_dt = dt.dropna()
print(new_dt.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# 22         60    130       101     300.0
# ...

# %%
#cleaning by filing the empty rows
dt.fillna(130)
print(dt.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# 22         60    130       101     300.0
# ...

# %%
#replacing or filling for a specific column
dt["Calories"].fillna(130, inplace = True)
print(dt.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# 22         60    130       101     300.0
# ...

# %%
#replacing with the mean
z = dt["Calories"].mean()
dt['Calories'].fillna(z, inplace = True)
print(dt.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# 22         60    130       101     300.0
# ...

# %%
dt.insert(2, column = "Date", value = "Nan")
print(dt.to_string())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-7f4245fd2057> in <cell line: 1>()
# ----> 1 dt.insert(2, column = "Date", value = "Nan")
#       2 print(dt.to_string())
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    4770         if not allow_duplicates and column in self.columns:
#    4771             # Should this be a different kind of error??
# -> 4772             raise ValueError(f"cannot insert {column}, already exists")
#    4773         if not isinstance(loc, int):
#    4774             raise TypeError("loc must be int")
#
# ValueError: cannot insert Date, already exists

# %%
dt["Date"] = pd.to_datetime(dt['Date'])
print(dt.to_string())
# Out:
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# <ipython-input-55-02dcc663659f> in <cell line: 1>()
# ----> 1 dt["Date"] = pd.to_datetime(dt['Date'])
#       2 print(dt.to_string())
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1044                 result = arg.tz_localize("utc")
#    1045     elif isinstance(arg, ABCSeries):
# -> 1046         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1047         if not cache_array.empty:
#    1048             result = arg.map(cache_array)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in _maybe_cache(arg, format, cache, convert_listlike)
#     248         unique_dates = unique(arg)
#     249         if len(unique_dates) < len(arg):
# ...

# %%
#replacing with median
y = dt["Pulse"].median()
dt["Pulse"].fillna(y, inplace = True)
print(dt.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# 22         60    130       101     300.0
# ...

# %%
#replacing values wrongly recorded
dt.loc[7,"Duration"]=30
print(dt.to_string())
# Out:
#      Duration  Pulse Date  Maxpulse  Calories
# 0          60    110  Nan       130     409.1
# 1          60    117  Nan       145     479.0
# 2          60    103  Nan       135     340.0
# 3          45    109  Nan       175     282.4
# 4          45    117  Nan       148     406.0
# 5          60    102  Nan       127     300.0
# 6          60    110  Nan       136     374.0
# 7          30    104  Nan       134     253.3
# 8          30    109  Nan       133     195.1
# 9          60     98  Nan       124     269.0
# 10         60    103  Nan       147     329.3
# 11         60    100  Nan       120     250.7
# 12         60    106  Nan       128     345.3
# 13         60    104  Nan       132     379.3
# 14         60     98  Nan       123     275.0
# 15         60     98  Nan       120     215.2
# 16         60    100  Nan       120     300.0
# 18         60    103  Nan       123     323.0
# 19         45     97  Nan       125     243.0
# ...

# %%
#removing duplicates
dt.drop_duplicates(inplace = True)
print(dt.to_string())
# Out:
#      Duration  Pulse Date  Maxpulse  Calories
# 0          60    110  Nan       130     409.1
# 1          60    117  Nan       145     479.0
# 2          60    103  Nan       135     340.0
# 3          45    109  Nan       175     282.4
# 4          45    117  Nan       148     406.0
# 5          60    102  Nan       127     300.0
# 6          60    110  Nan       136     374.0
# 7          30    104  Nan       134     253.3
# 8          30    109  Nan       133     195.1
# 9          60     98  Nan       124     269.0
# 10         60    103  Nan       147     329.3
# 11         60    100  Nan       120     250.7
# 12         60    106  Nan       128     345.3
# 13         60    104  Nan       132     379.3
# 14         60     98  Nan       123     275.0
# 15         60     98  Nan       120     215.2
# 16         60    100  Nan       120     300.0
# 18         60    103  Nan       123     323.0
# 19         45     97  Nan       125     243.0
# ...

# %%
#correlations in pandas
dt.corr()
# Out:
#           Duration     Pulse  Date  Maxpulse  Calories
# Duration  1.000000 -0.166961   NaN -0.000433  0.922826
# Pulse    -0.166961  1.000000   NaN  0.784994  0.015301
# Date           NaN       NaN   NaN       NaN       NaN
# Maxpulse -0.000433  0.784994   NaN  1.000000  0.195309
# Calories  0.922826  0.015301   NaN  0.195309  1.000000

# %%
#plotting in pandas
import matplotlib.pyplot as plt
dt.plot()
plt.show()

# %%
dt.plot(kind = 'scatter', x = 'Duration', y = 'Calories')
plt.show()

# %%
plt.scatter(dt["Duration"],dt["Calories"])
plt.xlabel("duration")
plt.ylabel("calories")
plt.show()

# %%
#creatinting train and test data
import numpy as np
msk = np.random.rand(len(dt)) < 0.8

# %%
msk
# Out:
# array([ True, False,  True,  True,  True,  True,  True, False,  True,
#        False,  True,  True,  True,  True,  True, False, False,  True,
#         True,  True,  True,  True,  True,  True,  True, False,  True,
#         True,  True,  True,  True,  True,  True,  True,  True, False,
#         True, False,  True, False,  True,  True,  True,  True,  True,
#         True, False, False,  True,  True, False, False,  True,  True,
#         True, False,  True,  True,  True,  True, False,  True,  True,
#         True,  True, False, False, False,  True,  True,  True,  True,
#         True, False,  True,  True,  True,  True, False, False,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True, False,  True, False, False,  True,  True,  True,
#        False,  True,  True, False,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
# ...

# %%
len(msk)
# Out:
# 157

# %%
count=0
for a in range(len(msk)):
  if(msk[a]==True):
    count= count+1
print(count)
# Out:
# 122

# %%
122/157
# Out:
# 0.7770700636942676

# %%
train = dt[msk]
test = dt[~msk]

# %%
#Simple regression model
plt.scatter(train["Duration"], train["Calories"])
plt.xlabel("Duration")
plt.ylabel("Calories")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#regression line
plt.scatter(train["Duration"], train['Calories'],  color='blue')
plt.plot(train_x, regr.coef_[0][0]*train_x + regr.intercept_[0], '-r')
plt.xlabel("duration")
plt.ylabel("calories")
# Out:
# Text(0, 0.5, 'calories')

# %%
#modelling

from sklearn import linear_model

regr = linear_model.LinearRegression()

train_x = np.asanyarray(train[['Duration']])
train_y = np.asanyarray(train[['Calories']])

regr.fit(train_x, train_y) # train the linear model
# The coefficients
print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)
# Out:
# Coefficients:  [[6.09274353]]
# Intercept:  [-1.2178864]

# %%
#getting the regressed value after knowint the constants
regr.coef_[0][0]*2 + regr.intercept_[0]
# Out:
# 10.967600661462061

# %%
from sklearn.metrics import r2_score

test_x = np.asanyarray(test[['Duration']])
test_y = np.asanyarray(test[["Calories"]])
test_y_ = regr.predict(test_x)

print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_ - test_y)))
print("Residual/root sum of squares (MSE): %.2f" % np.mean((test_y_ - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y , test_y_))
# Out:
# Mean absolute error: 67.84
# Residual/root sum of squares (MSE): 6346.03
# R2-score: 0.86

# %%
#Dataframes in pandas
import pandas as pd
vehicles ={
    "Means":["Matatu", "cars", "buses","Tuk tik","Motorbikes","Bicycles"],
    "Number":[325,145,589,234,1000,3456]

}
x = pd.DataFrame (vehicles)
print(x)
# Out:
#         Means  Number
# 0      Matatu     325
# 1        cars     145
# 2       buses     589
# 3     Tuk tik     234
# 4  Motorbikes    1000
# 5    Bicycles    3456

# %%
for y in x.index:
  if x.loc[y,"Number"]<300:
    x.loc[y,"Number"]=350
print(x.to_string())
# Out:
#         Means  Number
# 0      Matatu     325
# 1        cars     350
# 2       buses     589
# 3     Tuk tik     350
# 4  Motorbikes    1000
# 5    Bicycles    3456

# %%
for z in x.index:
  if x.loc[z,"Number"]>=1000:
    x.loc[z,"Number"]=990
print(x.to_string())
# Out:
#         Means  Number
# 0      Matatu     325
# 1        cars     350
# 2       buses     589
# 3     Tuk tik     350
# 4  Motorbikes     990
# 5    Bicycles     990

# %%
print(x.loc[0:3])
# Out:
#      Means  Number
# 0   Matatu     325
# 1     cars     145
# 2    buses     589
# 3  Tuk tik     234

# %%
#Series in  pandas
y = [134,265,489,90,56]
data = pd.Series(y ,index = ["p","q","r","s","t"])
print(data)
# Out:
# p    134
# q    265
# r    489
# s     90
# t     56
# dtype: int64
